# %%
# Kafta producer 
# This mimics the "real producer"
# This mimics the real producer
from kafka import KafkaProducer
import json

producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

import yfinance as yf 

# Define which stocks to follow 

tickers = ["AAPL", "MSFT", "GOOGL","TSLA"]
for ticker in tickers: 
    data = yf.Ticker (tickers[0], history (period ='id', interwal ="lm")).tail(1)
    price = data['Close'].iloc[0]
    message = {'ticker':tickers[0]},"price":float(price)}
    producer.send('stock_prices', value = message)
    print(message) 
    time.sleep(10)
